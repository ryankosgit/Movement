# %%
import coremltools as ct
import joblib
import numpy as np

# Load the saved model
rf = joblib.load("exercise_rf.pkl")

# Convert to Core ML
mlmodel = ct.converters.sklearn.convert(
    rf,
    input_features=[
        "p_ax","p_ay","p_az",
        "p_gx","p_gy","p_gz",
        "a_ax","a_ay","a_az",
        "a_gx","a_gy","a_gz"
    ],
    output_feature_names=["label"]
)

# Save to file
mlmodel.save("ExerciseClassifier.mlmodel")
print("✅ Saved Core ML model: ExerciseClassifier.mlmodel")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       6 rf = joblib.load("exercise_rf.pkl")
#       8 # Convert to Core ML
# ----> 9 mlmodel = ct.converters.sklearn.convert(
#      10     rf,
#      11     input_features=[
#      12         "p_ax","p_ay","p_az",
#      13         "p_gx","p_gy","p_gz",
#      14         "a_ax","a_ay","a_az",
#      15         "a_gx","a_gy","a_gz"
#      16     ],
#      17     output_feature_names=["label"]
#      18 )
#      20 # Save to file
#      21 mlmodel.save("ExerciseClassifier.mlmodel")
#
# File ~/Desktop/ai_atl_hack/ML/venv/lib/python3.12/site-packages/coremltools/converters/sklearn/_converter.py:148, in convert(sk_obj, input_features, output_feature_names)
#     144 from ...models import MLModel
#     145 # NOTE: Providing user-defined class labels will be enabled when
#     146 # several issues with the ordering of the classes are worked out.  For now,
#     147 # to use custom class labels, directly import the internal function below.
# --> 148 from ._converter_internal import _convert_sklearn_model
#     150 spec = _convert_sklearn_model(
#     151     sk_obj, input_features, output_feature_names, class_labels=None
#     152 )
#     154 model = MLModel(spec)
#
# File ~/Desktop/ai_atl_hack/ML/venv/lib/python3.12/site-packages/coremltools/converters/sklearn/_converter_internal.py:22
#      17     from sklearn.pipeline import Pipeline as sk_Pipeline
#      19 from collections import namedtuple as _namedtuple
# ---> 22 from . import (_SVC, _SVR, _decision_tree_classifier, _decision_tree_regressor,
#      23                _dict_vectorizer, _gradient_boosting_classifier,
#      24                _gradient_boosting_regressor, _imputer, _k_neighbors_classifier,
#      25                _linear_regression, _LinearSVC, _LinearSVR,
#      26                _logistic_regression, _normalizer, _NuSVC, _NuSVR,
#      27                _one_hot_encoder, _random_forest_classifier,
#      28                _random_forest_regressor, _standard_scaler, _ridge_regression)
#      30 _PIPELINE_INTERNAL_FEATURE_NAME = "__feature_vector__"
#      32 _converter_module_list = [
#      33     _dict_vectorizer,
#      34     _one_hot_encoder,
#    (...)     53     _ridge_regression
#      54 ]
#
# File ~/Desktop/ai_atl_hack/ML/venv/lib/python3.12/site-packages/coremltools/converters/sklearn/_decision_tree_classifier.py:16
#      13     from . import _sklearn_util
#      15 model_type = "classifier"
# ---> 16 sklearn_class = _tree.DecisionTreeClassifier
#      19 def convert(model, input_name, output_features):
#      20     """Convert a decision tree model to protobuf format.
#      21
#      22     Parameters
#    (...)     36         Protobuf representation of the model
#      37     """
#
# NameError: name '_tree' is not defined
